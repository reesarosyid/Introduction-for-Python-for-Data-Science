# %% [markdown]
# Nama    : Muhammad Reesa Rosyid
#
# Program : Python for Data science

# %% [markdown]
# # Pandas
#
# ## Definisi Pandas
#
# Pandas adalah paket Python open source yang paling sering dipakai untuk menganalisis data serta membangun sebuah machine learning. Pandas dibuat berdasarkan satu package lain bernama Numpy, yang mendukung arrays multi dimensi.
#
# ## Inisiasi Pandas

# %%
# import library
import numpy as np
import pandas as pd

# %% [markdown]
# ## Membaca file csv

# %%
df = pd.read_csv('nbaallelo.csv')

# %%
# Melihat besar data
df.shape

#(baris,kolom)
# Out:
# (126314, 23)

# %%
# Melihat baris data
len(df)
# Out:
# 126314

# %%
# Lihat isi data dari atas
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
# Lihat isi data 10 teratas
df.head(10)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
# 5          3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6          4  194611020PRO   NBA        1     1947  11/2/1946           1
# 7          4  194611020PRO   NBA        0     1947  11/2/1946           1
# 8          5  194611020STB   NBA        1     1947  11/2/1946           1
# 9          5  194611020STB   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id       fran_id  ...  win_equiv  opp_id      opp_fran  \
# 0            0     TRH       Huskies  ...  40.294830     NYK        Knicks
# ...

# %%
# Menampilkan semua kolom
pd.set_option("display.max.columns", None)
#pd.set_option("display.max.rows", None)
df.head(10)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
# 5          3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6          4  194611020PRO   NBA        1     1947  11/2/1946           1
# 7          4  194611020PRO   NBA        0     1947  11/2/1946           1
# 8          5  194611020STB   NBA        1     1947  11/2/1946           1
# 9          5  194611020STB   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id       fran_id  pts      elo_i      elo_n  win_equiv  \
# 0            0     TRH       Huskies   66  1300.0000  1293.2767  40.294830
# ...

# %%
# Lihat isi data 10 terbawah
df.tail(10)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126304      63153  201506070GSW   NBA        1     2015   6/7/2015
# 126305      63153  201506070GSW   NBA        0     2015   6/7/2015
# 126306      63154  201506090CLE   NBA        1     2015   6/9/2015
# 126307      63154  201506090CLE   NBA        0     2015   6/9/2015
# 126308      63155  201506110CLE   NBA        1     2015  6/11/2015
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 126304          98            1     CLE  Cavaliers   95  1708.1705  1716.8708
# ...

# %%
# Melihat info tipe data setiap kolom

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
# Statistik deskriptif sederhana
df.describe()
# Out:
#            gameorder        _iscopy        year_id     seasongame  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean    31579.000000       0.500000    1988.200374      43.533733
# std     18231.927643       0.500002      17.582309      25.375178
# min         1.000000       0.000000    1947.000000       1.000000
# 25%     15790.000000       0.000000    1975.000000      22.000000
# 50%     31579.000000       0.500000    1990.000000      43.000000
# 75%     47368.000000       1.000000    2003.000000      65.000000
# max     63157.000000       1.000000    2015.000000     108.000000
#
#          is_playoffs            pts          elo_i          elo_n  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean        0.063857     102.729982    1495.236055    1495.236055
# std         0.244499      14.814845     112.139945     112.461687
# min         0.000000       0.000000    1091.644500    1085.774400
# ...

# %% [markdown]
# ## Eksplorasi Data [EDA]

# %%
# Lihat team_id sering muncul berserta jumlah
# df['team_id'].value_counts
df.team_id.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         TRH
# 1         NYK
# 2         CHS
# 3         NYK
# 4         DTF
#          ...
# 126309    CLE
# 126310    GSW
# 126311    CLE
# 126312    CLE
# 126313    GSW
# Name: team_id, Length: 126314, dtype: object>

# %%
# save to file
#df["team_id"].value_counts().to_csv('team_id.csv')
df.team_id.value_counts().to_csv('team_id.csv')

# %%
df.fran_id.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0           Huskies
# 1            Knicks
# 2             Stags
# 3            Knicks
# 4           Falcons
#             ...
# 126309    Cavaliers
# 126310     Warriors
# 126311    Cavaliers
# 126312    Cavaliers
# 126313     Warriors
# Name: fran_id, Length: 126314, dtype: object>

# %% [markdown]
# ### Query sederhana

# %%
df.fran_id == "Lakers"
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 126309    False
# 126310    False
# 126311    False
# 126312    False
# 126313    False
# Name: fran_id, Length: 126314, dtype: bool

# %%
kondisi = df.fran_id == "Lakers"
df[kondisi]["team_id"]
# Out:
# 1136      MNL
# 1152      MNL
# 1159      MNL
# 1170      MNL
# 1183      MNL
#          ...
# 126016    LAL
# 126052    LAL
# 126086    LAL
# 126115    LAL
# 126137    LAL
# Name: team_id, Length: 6024, dtype: object

# %%
# Konfersi tipe data
df['date_game'] = pd.to_datetime(df['date_game'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  datetime64[ns]
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
#Mengambil data game yang diadakan bulan februari
kondisi = df['date_game'].dt.month==2
df[kondisi].head(10)
# Out:
#      gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 390        196  194702010NYK   NBA        0     1947 1947-02-01          35
# 391        196  194702010NYK   NBA        1     1947 1947-02-01          36
# 392        197  194702010PRO   NBA        0     1947 1947-02-01          35
# 393        197  194702010PRO   NBA        1     1947 1947-02-01          37
# 394        198  194702010STB   NBA        1     1947 1947-02-01          35
# 395        198  194702010STB   NBA        0     1947 1947-02-01          36
# 396        199  194702020CHS   NBA        0     1947 1947-02-02          37
# 397        199  194702020CHS   NBA        1     1947 1947-02-02          36
# 398        200  194702020CLR   NBA        0     1947 1947-02-02          36
# 399        200  194702020CLR   NBA        1     1947 1947-02-02          37
#
#      is_playoffs team_id       fran_id  pts      elo_i      elo_n  win_equiv  \
# ...

# %%
kondisi1 = df['date_game'].dt.month==3
kondisi2 = df['date_game'].dt.day==11
df[kondisi1 & kondisi2].head(10)
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 570         286  194703110CLR   NBA        0     1947 1947-03-11          51
# 571         286  194703110CLR   NBA        1     1947 1947-03-11          55
# 572         287  194703110GSW   NBA        0     1947 1947-03-11          53
# 573         287  194703110GSW   NBA        1     1947 1947-03-11          54
# 574         288  194703110TRH   NBA        1     1947 1947-03-11          52
# 575         288  194703110TRH   NBA        0     1947 1947-03-11          53
# 1050        526  194803110BLB   NBA        0     1948 1948-03-11          45
# 1051        526  194803110BLB   NBA        1     1948 1948-03-11          44
# 1052        527  194803110GSW   NBA        1     1948 1948-03-11          44
# 1053        527  194803110GSW   NBA        0     1948 1948-03-11          45
#
#       is_playoffs team_id    fran_id  pts      elo_i      elo_n  win_equiv  \
# ...

# %%
kondisi = df['team_id'] == "MNL"
df[kondisi]['date_game'].min()
# Out:
# Timestamp('1948-11-04 00:00:00')

# %%
df.loc[df["team_id"] == "MNL", "date_game"].min()
# Out:
# Timestamp('1948-11-04 00:00:00')

# %% [markdown]
# ### Agregasi

# %%
kondisi = df['team_id'] == "MNL"
df[kondisi]['date_game'].agg(("min","max"))
# Out:
# min   1948-11-04
# max   1960-03-26
# Name: date_game, dtype: datetime64[ns]

# %%
kondisi = df['team_id'] == "MNL"
df[kondisi]['win_equiv'].agg(("min","max", "mean", "std"))
# Out:
# min     24.525501
# max     66.217308
# mean    45.702914
# std     10.443832
# Name: win_equiv, dtype: float64

# %% [markdown]
# ## Deep Dive to Pandas
#
# ### Tipe Data

# %%
data = [0, 0.25, 0.5, 0.75, 1]
np_data = np.array(data)
ser_data = pd.Series(data)

# %%
# List
data
# Out:
# [0, 0.25, 0.5, 0.75, 1]

# %%
# Array
np_data
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
# Series
ser_data
# Out:
# 0    0.00
# 1    0.25
# 2    0.50
# 3    0.75
# 4    1.00
# dtype: float64

# %%
ser_data.values
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
ser_data.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %% [markdown]
# ### Data Index

# %%
ser_data_idx =pd.Series(data, index=['a','b','c','d','e'])

# %%
ser_data_idx
# Out:
# a    0.00
# b    0.25
# c    0.50
# d    0.75
# e    1.00
# dtype: float64

# %%
my_dict = {'kaset':100000,
           'CD':50000,
           'DVD':200000}
ser_dict = pd.Series(my_dict)
ser_dict
# Out:
# kaset    100000
# CD        50000
# DVD      200000
# dtype: int64

# %% [markdown]
# ### DataFrame

# %%
nilai = [[76, 80, 77, 90],
        [90, 85, 60, 70],
        [88, 89,78, 90],
        [60, 50, 70, 40]] #mat, ipa, bindo, bing
df = pd.DataFrame(nilai, columns=['matematika', 'ipa', 'bahasa_indonesia', 'bahasa_inggris'], index=['Budi', 'Danu', 'Eka', 'Wendi'] )
df
# Out:
#        matematika  ipa  bahasa_indonesia  bahasa_inggris
# Budi           76   80                77              90
# Danu           90   85                60              70
# Eka            88   89                78              90
# Wendi          60   50                70              40

# %%
df['matematika']
# Out:
# Budi     76
# Danu     90
# Eka      88
# Wendi    60
# Name: matematika, dtype: int64

# %%
df['matematika']['Budi']
# Out:
# 76

# %% [markdown]
# Tips : Pada dataframe yang dipanggil kolom dulu baru baris

# %% [markdown]
# ## Perbedaan loc dan iloc

# %%
data = [0, 0.25, 0.5, 0.75, 1]
ser_data_idx =pd.Series(data, index=['a','b','c','d','e'])
ser_data_idx
# Out:
# a    0.00
# b    0.25
# c    0.50
# d    0.75
# e    1.00
# dtype: float64

# %% [markdown]
# ### Loc
#
# Memanggil data dengan explisit index

# %%
ser_data_idx.loc['c']
# Out:
# 0.5

# %%
# Slicing loc 
ser_data_idx.loc['c':'e']
# Out:
# c    0.50
# d    0.75
# e    1.00
# dtype: float64

# %% [markdown]
# ### Iloc
#
# Memanggil data dengan implisit index

# %%
ser_data_idx.iloc[1]
# Out:
# 0.25

# %%
# Slicing Iloc
ser_data_idx.iloc[1:4]
# Out:
# b    0.25
# c    0.50
# d    0.75
# dtype: float64
